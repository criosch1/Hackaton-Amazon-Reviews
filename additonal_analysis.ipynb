# %%
review_breakdown = df.groupby('asin')[('overall')].value_counts()
review_breakdown
# Out:
# asin        overall
# 4639725043  5.0        17
#             4.0         6
#             3.0         5
#             1.0         2
# 4639725183  5.0        10
#                        ..
# B01HJCUNOO  5.0         6
#             4.0         3
#             2.0         1
# B01HJF6FRA  5.0         5
#             3.0         1
# Name: overall, Length: 131253, dtype: int64

# %%
df5break =df[df['overall']== 5.0]
df5break
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 0            5.0      True  11 19, 2014  A1QVBUH9E1V6I8  4639725183
# 1            5.0      True  10 13, 2016  A3GEOILWLK86XM  4639725183
# 2            5.0      True  11 21, 2015  A32RD6L701BIGP  4639725183
# 3            5.0      True  08 12, 2015  A2UY1O1FBGKIE6  4639725183
# 4            5.0      True  05 28, 2015  A3QHVBQYDV7Z6U  4639725183
# ...          ...       ...          ...             ...         ...
# 1143852      5.0      True   04 6, 2018  A2QOJJS8WB47AH  B01HJ2OFYI
# 1143855      5.0      True   09 8, 2017  A223YRQH2Z5T1D  B01HJF6FRA
# 1143856      5.0      True   08 4, 2017  A38GDA4TB9EILT  B01HJF6FRA
# 1143857      5.0      True   07 4, 2017  A2025PN7HDC5BO  B01HJF6FRA
# 1143858      5.0      True   06 7, 2017  A1NY7XWC7EPQOA  B01HJF6FRA
#
#             reviewerName                                         reviewText  \
# ...

# %%
review_avg_all= df.groupby('asin')['overall'].mean().
review_avg_all

# %%
review_avg= df.groupby('asin')['overall'].mean().
review_avg
# Out:
# asin
# 4639725043    4.200000
# 4639725183    4.833333
# 5463213682    4.888889
# 9742356831    4.552083
# B00004S1C5    4.000000
#                 ...
# B01HJ2OFYI    4.416667
# B01HJ4FWGG    4.444444
# B01HJ7QPKU    4.250000
# B01HJCUNOO    4.400000
# B01HJF6FRA    4.666667
# Name: overall, Length: 41320, dtype: float64

# %%
review_avg= df.groupby('asin')['overall'].mean().sort_values(ascending=False).to_frame()
review_avg
# Out:
#             overall
# asin
# B006LEEWL2      5.0
# B00AFJMJ0K      5.0
# B013KOSVX0      5.0
# B00AEVXY4E      5.0
# B00AF0ZFE6      5.0
# ...             ...
# B004TJF39G      1.2
# B000ZB3CRC      1.0
# B0014AJV82      1.0
# B000WW6VZO      1.0
# B001684NJO      1.0
#
# [41320 rows x 1 columns]

# %%
df_RA_value_counts = pd.DataFrame(review_avg)
df_RA_value_counts = df_RA_value_counts[df_RA_value_counts['overall']== 5.0]
df_RA_value_counts
# Out:
#             overall
# asin
# B006LEEWL2      5.0
# B00AFJMJ0K      5.0
# B013KOSVX0      5.0
# B00AEVXY4E      5.0
# B00AF0ZFE6      5.0
# ...             ...
# B004ASBLJ2      5.0
# B01AO4KIC6      5.0
# B01HH7ITOM      5.0
# B01FWOCCD6      5.0
# B01HGBBV5I      5.0
#
# [3381 rows x 1 columns]

# %%
df_RA_value_counts = df_RA_value_counts.reset_index()

# %%
df_RA_value_counts
# Out:
#             asin  overall
# 0     B006LEEWL2      5.0
# 1     B00AFJMJ0K      5.0
# 2     B013KOSVX0      5.0
# 3     B00AEVXY4E      5.0
# 4     B00AF0ZFE6      5.0
# ...          ...      ...
# 3376  B004ASBLJ2      5.0
# 3377  B01AO4KIC6      5.0
# 3378  B01HH7ITOM      5.0
# 3379  B01FWOCCD6      5.0
# 3380  B01HGBBV5I      5.0
#
# [3381 rows x 2 columns]

# %%
merged_df = pd.merge(df, df_RA_value_counts, on=['asin'], how='inner')
merged_df.head()
# Out:
#    overall_x  verified   reviewTime      reviewerID        asin  \
# 0        5.0      True  08 12, 2017  A1J7QZ20NPHHBH  B0000D17HA
# 1        5.0      True  04 27, 2017  A3BZLV98AGWLLV  B0000D17HA
# 2        5.0      True   02 3, 2017   AYAODCZKONJU1  B0000D17HA
# 3        5.0      True  01 26, 2017   AYBZ2HGNTK5OO  B0000D17HA
# 4        5.0      True   02 3, 2016  A24FOYF98K3FIO  B0000D17HA
#
#         reviewerName                                         reviewText  \
# 0               Kath  These are a little larger than pastina.  We us...
# 1         LadySelene  I LOVE these, I've used them for YEARS. I do w...
# 2                  *                        Always my all-time pasta!!!
# 3  RitaVille Grandma                      Makes a great fruit salad....
# 4           Alohagal  So hard to find this any more.  Great to have ...
#
#                  summary unixReviewTime vote style image  overall_y
# 0       Love this pasta.     2017-08-12  NaN   NaN   NaN        5.0
# ...

# %%
merged_df.shape
# Out:
# (23565, 13)

# %%
# getting list of all names
review = merged_df['reviewText'].tolist()
Top_product_review = []
for name in review:
    name = str(name).split()
    for word in name:
        Top_product_review.append(word.lower())

# %%
print(Top_product_review[:30])
# Out:
# ['these', 'are', 'a', 'little', 'larger', 'than', 'pastina.', 'we', 'use', 'it', 'in', 'chicken', 'soup', 'and', 'sometimes', 'swirl', 'in', 'an', 'egg', 'or', 'two', 'for', 'a', 'heartier', 'meal.', 'you', 'can', 'also', 'just', 'have']

# %%
def set_clean(text):
    set_stop_words = set(stopwords.words('english'))
    return [w for w in text if w.lower() not in set_stop_words]

# %%
Top_filtered_words_5 = set_clean(Top_product_review)

# %%
Top_sum_words_count_5 = Counter(Top_filtered_words_5).most_common()
Top_sum_words_count_5 = Top_sum_words_count_5[:25]

# %%
Top_df_reviews_5 = pd.DataFrame(Top_sum_words_count_5)
Top_df_reviews_5.head(25)
# Out:
#           0     1
# 0     great  5413
# 1      love  4796
# 2      good  4439
# 3      like  4040
# 4       use  2873
# 5       one  2588
# 6     taste  2568
# 7      best  2265
# 8    flavor  2211
# 9       tea  1905
# 10   really  1866
# 11     make  1821
# 12      get  1820
# 13  product  1726
# 14      buy  1709
# 15     find  1566
# 16   little  1558
# 17      it.  1557
# 18     also  1486
# 19     much  1458
# 20        -  1455
# 21    would  1445
# 22     i've  1423
# 23     used  1352
# 24     nice  1208

# %%
Top_df_reviews_5.rename(columns={0:"Words", 1:"Count"}, inplace=True)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
fig.suptitle('MOST COMMOMNLY Used Words in Amazon Grocery and Gourmet TOP PRODUCT Reviews', fontsize=20)
sns.barplot(x='Words', y='Count', data=Top_df_reviews_5, ax=ax)
plt.xticks(rotation=80)
plt.show()

# %%
Top_df_reviews_5.to_csv('Top_df_reviews_5.csv', header=True, index=False)

# %%
MY DATAFRAME WITH ADDED MEAN INFO. (ONLY CHANGE)

# %%
df.groupby('asin')['overall'].transform('mean')
# gapminder.groupby('continent').lifeExp.transform('mean')
# Out:
# 0          4.833333
# 1          4.833333
# 2          4.833333
# 3          4.833333
# 4          4.833333
#              ...
# 1143855    4.666667
# 1143856    4.666667
# 1143857    4.666667
# 1143858    4.666667
# 1143859    4.666667
# Name: overall, Length: 1143860, dtype: float64

# %%
df['mean'] = df.groupby('asin')['overall'].transform('mean')

# %%
df.drop(['image', 'style', 'vote', 'reviewTime'], axis = 1, inplace=True)

# %%
df
# Out:
#          overall  verified      reviewerID        asin     reviewerName  \
# 0            5.0      True  A1QVBUH9E1V6I8  4639725183   Jamshed Mathur
# 1            5.0      True  A3GEOILWLK86XM  4639725183        itsjustme
# 2            5.0      True  A32RD6L701BIGP  4639725183  Krystal Clifton
# 3            5.0      True  A2UY1O1FBGKIE6  4639725183          U. Kane
# 4            5.0      True  A3QHVBQYDV7Z6U  4639725183         The Nana
# ...          ...       ...             ...         ...              ...
# 1143855      5.0      True  A223YRQH2Z5T1D  B01HJF6FRA        flint5292
# 1143856      5.0      True  A38GDA4TB9EILT  B01HJF6FRA   Moriah Bolyard
# 1143857      5.0      True  A2025PN7HDC5BO  B01HJF6FRA              M.C
# 1143858      5.0      True  A1NY7XWC7EPQOA  B01HJF6FRA       Greensboro
# 1143859      3.0      True  A1P0X9E6F99J4T  B01HJF6FRA          Qoyllor
#
#                                                 reviewText  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1143860 entries, 0 to 1143859
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   overall         1143860 non-null  float64
#  1   verified        1143860 non-null  bool
#  2   reviewerID      1143860 non-null  object
#  3   asin            1143860 non-null  object
#  4   reviewerName    1143722 non-null  object
#  5   reviewText      1143470 non-null  object
#  6   summary         1143641 non-null  object
#  7   unixReviewTime  1143860 non-null  datetime64[ns]
#  8   mean            1143860 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(2), object(5)
# memory usage: 119.6+ MB

# %%
sns.scatterplot(x = 'mean', y = "asin", data=df )
plt.show()

# %%
# my new dataframe with the mean of all reviews included
df.to_csv('df.csv', header=True, index=False)

# %%
# your original data for all 5 star reviews in gourmet 
df_reviews_5.to_csv('df_reviews_5.csv', header=True, index=False)
